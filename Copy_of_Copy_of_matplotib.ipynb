# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanush1234567890/python-programs/blob/main/Copy_of_Copy_of_matplotib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## plotting

# %%
import matplotlib.pyplot as csk
import numpy as jp
xpoints = np.array([0, 8])
ypoints = np.array([0, 400])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as apj
import numpy as nct
xpoints = np.array([3, 12])
ypoints = np.array([1, 50])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as df
import numpy as fg
xpoints = np.array([7, 12])
ypoints = np.array([5, 22])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as yu
import numpy as gj
xpoints = np.array([3, 5, 8, 10])
ypoints = np.array([1, 2, 7, 30])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as ol
import numpy as ad
ypoints = np.array([1, 4, 5, 9, 6, 12])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# ## markers

# %%
import matplotlib.pyplot as bjp
import numpy as at
ypoints = np.array([1, 7, 0, 9])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as jl
import numpy as kj
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = '^')
plt.show()

# %% [markdown]
# ## line style

# %%
import matplotlib.pyplot as kco
import numpy as pd
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as jl
import numpy as kj
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
import matplotlib.pyplot as jl
import numpy as kj
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# ## line colour

# %%
import matplotlib.pyplot as bc
import numpy as bj
ypoints = np.array([2, 18, 11, 20])
plt.plot(ypoints, color = 'g')
plt.show()

# %%
import matplotlib.pyplot as bc
import numpy as bj
ypoints = np.array([4, 6, 8, 10])
plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# ## line width

# %%
import matplotlib.pyplot as fg
import numpy as av
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linewidth = '30.5')
plt.show()

# %%
import matplotlib.pyplot as srh
import numpy as mi
y1 = np.array([3, 8, 6, 11])
y2 = np.array([6, 2, 4, 11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as uy
import numpy as mmo
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# ## lables plot

# %%
import numpy as csk
import matplotlib.pyplot as kcpd
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.xlabel("votes")
plt.ylabel("districts")
plt.show()

# %%
import numpy as ds
import matplotlib.pyplot as te
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.title("class rank")
plt.xlabel("average maeks")
plt.ylabel("students")
plt.show()

# %%
import numpy as op
import matplotlib.pyplot as vd
x = op.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = op.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
vd.title("districts", fontdict = font1)
vd.xlabel("votes", fontdict = font2)
vd.ylabel("ranks", fontdict = font2)
vd.plot(x, y)
vd.show()

# %% [markdown]
# ## pie charts

# %%
import matplotlib.pyplot as csk
import numpy as ae
y = np.array([35, 25, 25, 15])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as ap
import numpy as op
y = op.array([30, 25, 20, 25])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
ap.pie(y, labels = mylabels)
ap.show()

# %%
import matplotlib.pyplot as ad
import numpy as ap
y = ap.array([35, 25, 25, 15])
mylabels = ["telugu", "Biology", "Chemistry", "science"]
myexplode = [0.2, 0, 0, 0]
ad.pie(y, labels = mylabels, explode = myexplode)
ad.show()

# %%
import matplotlib.pyplot as un
import numpy as ap
y = ap.array([25, 35, 15, 25])
mylabels = ["social", "telugu", "python", "english"]
mycolors = ["red", "blue", "green", "brown"]
un.pie(y, labels = mylabels, colors = mycolors)
un.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
y = op.array([30, 20, 25, 25])
mylabels = ["maths", "Biology", "Chemistry", "hindi"]
vd.pie(y, labels = mylabels)
vd.legend()
vd.show()

# %% [markdown]
# ## bars

# %%
import matplotlib.pyplot as vd
import numpy as op
subject = op.array(["maths", "science", "biology", "telugu"])
marks = op.array([39, 65, 32, 25])
vd.bar(x,y)
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array(["science", "Biology", "maths", "telugu"])
y = op.array([39, 84, 41, 90])
vd.barh(x, y)
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array(["maths", "Biology", "science", "hindi"])
y = op.array([34, 68, 12, 60])
vd.barh(x, y, height = 0.1)
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array(["maths", "Biology", "sCience", "telugu"])
y = op.array([34, 87, 61, 100])
vd.bar(x, y, color = "green")
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array(["maths", "Biology", "sCience", "telugu"])
y = op.array([34, 87, 61, 100])
vd.bar(x, y, color = "violet")
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array(["history", "science", "biology", "maths"])
y = op.array([36, 83, 51, 60])
vd.bar(x, y, width = 0.6)
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array(["english", "Biology", "science", "maths"])
y = op.array([34, 86, 41, 100])
vd.bar(x, y, width = 0.1)
vd.show()

# %% [markdown]
# ## grids

# %%
import numpy as op
import matplotlib.pyplot as vd
x = op.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = op.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
vd.title("subject")
vd.xlabel("marks")
vd.ylabel("rank")
vd.plot(x, y)
vd.grid()
vd.show()

# %%
import numpy as op
import matplotlib.pyplot as vd
x = op.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = op.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
vd.title("subject|")
vd.xlabel("marks")
vd.ylabel("rank")
vd.plot(x, y)
vd.grid(axis = 'x')
vd.show()

# %%
import numpy as op
import matplotlib.pyplot as vd
x = op.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = op.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
vd.title("Subject")
vd.xlabel("marks")
vd.ylabel("rank")
vd.plot(x, y)
vd.grid(color = 'green', linestyle = '--', linewidth = 0.9)
vd.show()

# %%
import numpy as vd
import matplotlib.pyplot as op
x = vd.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = vd.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
op.title("tournments")
op.xlabel("matches")
op.ylabel("runs")
op.plot(x, y)
op.grid(axis = 'y')
op.show()

# %% [markdown]
# ## scatter

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = op.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
vd.scatter(x, y)
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op

#day one, the age and speed of 13 cars:
x = op.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = op.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
vd.scatter(x, y)
#day two, the age and speed of 15 cars:
x = op.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = op.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
vd.scatter(x, y)
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = op.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = op.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
vd.scatter(x, y, c=colors)
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = op.array([59,56,17,58,131,36,303,57,54,72,73,35,83])
colors = op.array([1, 16, 26, 33, 60, 46, 50, 55, 66, 50, 30, 30, 100])
vd.scatter(x, y, c=colors, cmap='viridis')
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = op.array([59,56,17,58,131,36,303,57,54,72,73,35,83])
colors = op.array([1, 16, 26, 33, 60, 46, 50, 55, 66, 50, 30, 30, 100])
vd.scatter(x, y, c=colors, cmap='viridis')
vd.colorbar()
vd.show()

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = op.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
vd.scatter(x, y, color = 'blue')
x = op.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = op.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
vd.scatter(x, y, color = 'yellow')
vd.show()

# %%
import matplotlib.pyplot as vd 
vd.scatter( 0 , 0 , s = 7000 ) 
vd.xlim( -1.24 , 1.43 ) 
vd.ylim( -1.25 , 1.43 ) 
vd.title( "Scatter plot of points Circle" ) 
vd.show()

# %% [markdown]
# ## histograms

# %%
import matplotlib.pyplot as vd
import numpy as op
x = op.random.normal(120, 73, 643)
vd.hist(x)
vd.show()

# %% [markdown]
# ## subplot

# %%
import matplotlib.pyplot as vd
import numpy as op
#plot 1:
x = op.array([0, 1, 2, 3])
y = op.array([3, 8, 1, 10])
vd.subplot(2, 1, 1)
vd.plot(x,y,color="yellow")
#plot 2:
x = op.array([0, 1, 2, 3])
y = op.array([10, 20, 30, 40])
vd.subplot(2, 1, 2)
vd.plot(x,y,color="green")
vd.show()
